# %% [markdown]
# # Assignment 2 (K mean+ Aglomerative + Purity + DBSCAN)
#
#
# ## Assignment instructions
#
# 1. Carefully read and follow all instructions.
# 2. No Late submisison Would be Accepted
# 3. You can search the basics of python, concepts, and syntax online. Copy solution from internet would result into 0.
# 4. Do keep in mind that sharing the code, discussing it is highly unethical, and all actions would be considered as plagiarism.
# 5. Plagiarism will result in serious penalty
# 6. I'll eveluate on the basis of resultant as you guys are using built in functions.
# 7. keep code clean and precise, its part of your assignment grading. Doing a hectic code would result in -ve marking
#
# ###### Instruction - rename this file as rollnumber_ass2; for example
# ###### 20l-1212_ass2

# %%
# import necessory libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.metrics import pairwise_distances, accuracy_score
from sklearn.datasets import make_circles
from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
import time
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import accuracy_score
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.metrics import completeness_score

# %% [markdown]
# # Task1:
# You need to create blobs with onlt 2 dimentions.
#
# Number of nodes equal to your roll number
#
# #### eg: 20l-1212= 1212 nodes
#
# All of you understood the code of blob and circle that have been demonstrated in labs
#
# Manipulate the value in that code and regenerate 5 datasets, such those datsets are near approximation of below images
#
# ## NOTE : The outputs fields are also shared.

# %% [markdown]
# ##### Dataset 1
# ![img1.PNG](attachment:img1.PNG)

# %% [markdown]
# ##### Dataset 2
# ![img2.PNG](attachment:img2.PNG)

# %% [markdown]
# ##### Dataset 3
# ![img3.PNG](attachment:img3.PNG)

# %% [markdown]
# ##### Dataset 4
# ![img4.PNG](attachment:img4.PNG)

# %% [markdown]
# ##### Dataset 5
# ![img5.PNG](attachment:img5.PNG)

# %%
X, y = make_blobs(n_samples=5675, centers= [(0, 0), (0.5,0.5), (1, 1)] , cluster_std=[0.05, 0.2, 0.05]  , random_state=42)
filename = f"dataset1.csv"
np.savetxt(filename, np.concatenate([X, y.reshape(-1,1)], axis=1), delimiter=",")
X[y == 0, 0] = X[y == 0, 0]*1
X[y == 1, 1] =X[y == 1, 1]* 1
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
X, y = make_moons(n_samples = 5675, noise = 0.045)
filename = f"dataset2.csv"
np.savetxt(filename, np.concatenate([X, y.reshape(-1,1)], axis=1), delimiter=",")
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
X,y= make_blobs(n_samples=5675, centers=[(18,18), (10,10), (2,2)] )
filename = f"dataset3.csv"
np.savetxt(filename, np.concatenate([X, y.reshape(-1,1)], axis=1), delimiter=",")
X = np.dot(X, [[0.4, -0.8], [-0.8, 0.4]])
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
x1,y1 = make_circles(n_samples=5675, noise = 0.025,factor=0.458)
X, y = make_circles(n_samples=5675,noise = 0.025)
plt.scatter(X[:,0],X[:,1],  facecolors='none', edgecolor='blue')
plt.scatter(x1[:,0],x1[:,1],  facecolors='none', edgecolor='blue')
filename = f"dataset4.csv"
np.savetxt(filename, np.concatenate([X, y.reshape(-1,1)], axis=1), delimiter=",")

# %%
X, y = make_blobs(n_samples=5675, centers= [(0,0),(0,4),(0,-4),(4,0),(-4,0)],random_state=42)
filename = f"dataset5.csv"
np.savetxt(filename, np.concatenate([X, y.reshape(-1,1)], axis=1), delimiter=",")
plt.scatter(X[:,0], X[:,1])
plt.xlim(-4,4)
plt.ylim(-4,4)
plt.show()

# %% [markdown]
# # Task2 (Time+ Purity + Plot):
# Nice work! Pat on you shoulder
#
# #### Part(A)
#
# Now lets use all of learnt functions from previous labs and apply each and every one of them on these 5 datsets.
#
# 1. Kmean
# 2. Aglomerative (single linkage)
# 3. Aglomerative (Avg linkage)
# 4. Aglomerative (Complete linkage)
# 5. Dbscan
#     * Run for different values of the number of clusters.
#
# You also need to print purity at the end of each plot & don't forget to report the time it takes by each algo in each
#
# After each output state your conclusive sentence about it
#
#
# ### Note: There are total 25 outputs, each with 2 fields (time & purity). Displaying output with default colors would results in 0 for that section

# %%
# K mean - case 1
# Code which output time, purity, distiniugable plot 
#conclusive line

data = pd.read_csv('dataset1.csv')
 
X = data.iloc[:, :-1].values
 
kmeans = KMeans(n_clusters=3, random_state=42)
 
start_time = time.time()
kmeans.fit(X)
end_time = time.time()
 
y_pred = kmeans.predict(X)
 
y_true = data.iloc[:, -1].values
purity = accuracy_score(y_true, y_pred)
 
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1],c='green')
plt.title('K-means clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print('Time taken: {:.2f} seconds'.format(end_time - start_time))
print('Purity score: {:.2f}'.format(purity))
# Out:
# Time taken: 0.04 seconds
# Purity score: 0.34

# %%
# K mean - case 2
# Code which output time, purity, distiniugable plot 
#conclusive line
data = pd.read_csv('dataset2.csv')
 
X = data.iloc[:, :-1].values
 
kmeans = KMeans(n_clusters=3, random_state=42)
 
start_time = time.time()
kmeans.fit(X)
end_time = time.time()
 
y_pred = kmeans.predict(X)
 
y_true = data.iloc[:, -1].values
purity = accuracy_score(y_true, y_pred)
 
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1],c='green')
plt.title('K-means clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print('Time taken: {:.2f} seconds'.format(end_time - start_time))
print('Purity score: {:.2f}'.format(purity))
# Out:
# Time taken: 0.07 seconds
# Purity score: 0.22

# %%
# K mean - case 3
# Code which output  time, purity, distiniugable plot 
#conclusive line
data = pd.read_csv('dataset3.csv')
 
X = data.iloc[:, :-1].values
 
kmeans = KMeans(n_clusters=3, random_state=42)
 
start_time = time.time()
kmeans.fit(X)
end_time = time.time()
 
y_pred = kmeans.predict(X)
 
y_true = data.iloc[:, -1].values
purity = accuracy_score(y_true, y_pred)
 
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1],c='green')
plt.title('K-means clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print('Time taken: {:.2f} seconds'.format(end_time - start_time))
print('Purity score: {:.2f}'.format(purity))
# Out:
# Time taken: 0.03 seconds
# Purity score: 1.00

# %%
# K mean - case 4
# Code which output time, purity, distiniugable plot 
#conclusive line
data = pd.read_csv('dataset4.csv')
 
X = data.iloc[:, :-1].values
 
kmeans = KMeans(n_clusters=3, random_state=42)
 
start_time = time.time()
kmeans.fit(X)
end_time = time.time()
 
y_pred = kmeans.predict(X)
 
y_true = data.iloc[:, -1].values
purity = accuracy_score(y_true, y_pred)
 
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1],c= y_pred)
plt.scatter(X[:, 0], X[:, 1],c='green')
plt.title('K-means clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print('Time taken: {:.2f} seconds'.format(end_time - start_time))
print('Purity score: {:.2f}'.format(purity))
# Out:
# Time taken: 0.04 seconds
# Purity score: 0.33

# %%
# K mean - case 5
# Code which output time, purity, distiniugable plot 
#conclusive line
data = pd.read_csv('dataset5.csv')
 
X = data.iloc[:, :-1].values
 
kmeans = KMeans(n_clusters=3, random_state=42)

# Fit KMeans object to data
start_time = time.time()
kmeans.fit(X)
end_time = time.time()
 
y_pred = kmeans.predict(X)
 
y_true = data.iloc[:, -1].values
purity = accuracy_score(y_true, y_pred)
 
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1],c='green')
plt.title('K-means clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print('Time taken: {:.2f} seconds'.format(end_time - start_time))
print('Purity score: {:.2f}'.format(purity))
# Out:
# Time taken: 0.06 seconds
# Purity score: 0.23

# %%
# Aglomerative 1 - case 1
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset1.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='single')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with Single Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.20 seconds
# Purity score: 0.33345082833979556

# %%
# Aglomerative 1 - case 2
# Code whihc ourput time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset2.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='single')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with Single Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.20 seconds
# Purity score: 0.0

# %%
# Aglomerative 1 - case 3
# Code whihc ourput time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset3.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='single')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with Single Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.16 seconds
# Purity score: 0.3332745858301022

# %%
# Aglomerative 1 - case 4
# Code whihc ourput time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset4.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='single')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with Single Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.17 seconds
# Purity score: 0.9998237574903066

# %%
# Aglomerative 1 - case 5
# Code whihc ourput time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset5.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='single')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with Single Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:.2f}")
# Out:
# Time taken: 0.16 seconds
# Purity score: 0.20

# %%
# Aglomerative 2 - case 1
# Code which output time, purity, distinguishable plot 
#conclusive line

 
 
data = pd.read_csv('dataset1.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.93 seconds
# Purity score: 0.0026436376454000705

# %%
# Aglomerative 2 - case 2
# Code which output time, purity, distinguishable plot 
#conclusive line

 
 
data = pd.read_csv('dataset2.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.83 seconds
# Purity score: 0.5567500881212548

# %%
# Aglomerative 2 - case 3
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset3.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.85 seconds
# Purity score: 0.3332745858301022

# %%
# Aglomerative 2 - case 4
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset4.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.74 seconds
# Purity score: 0.3808600634473035

# %%
# Aglomerative 2 - case 5
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset5.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# Perform agglomerative clustering with single linkage
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.74 seconds
# Purity score: 0.17677123722241805

# %%
# Aglomerative 3 - case 1
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset1.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
 
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='complete')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.88 seconds
# Purity score: 0.09094113500176243

# %%
# Aglomerative 3 - case 2
# Code whihc ourput time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset2.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
 
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='complete')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.78 seconds
# Purity score: 0.5921748325696158

# %%
# Aglomerative 3 - case 3
# Code which output time, purity, distinguishable plot 
#conclusive line

 
data = pd.read_csv('dataset3.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
 
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='complete')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.75 seconds
# Purity score: 0.33345082833979556

# %%
# Aglomerative 3 - case 4
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset4.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
 
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='complete')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.66 seconds
# Purity score: 0.3727529080014099

# %%
# Aglomerative 3 - case 5
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset5.csv')
 
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
 
start_time = time.time()
clustering = AgglomerativeClustering(n_clusters=3, linkage='complete')
y_pred = clustering.fit_predict(X)
end_time = time.time()
 
purity = accuracy_score(y, y_pred)
 
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('Agglomerative Clustering with average Linkage')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print(f"Time taken: {end_time - start_time:.2f} seconds")
print(f"Purity score: {purity:}")
# Out:
# Time taken: 0.67 seconds
# Purity score: 0.25519915403595345

# %%
# Dbscan - case 1
# Code which output time, purity, distinguishable plot
#conclusive line
 
 
data = pd.read_csv('dataset1.csv')
 
X = data.iloc[:, 0:2].values
start_time = time.time()
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(X)
elapsed_time = time.time() - start_time 
y_true = data.iloc[:, 2].values
purity = completeness_score(y_true, labels)
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print("Time taken: ", elapsed_time)
print("Purity: ", purity)
# Out:
# Time taken:  0.17218828201293945
# Purity:  1.0

# %%
# Dbscan - case 2
# Code which output time, purity, distinguishable plot
#conclusive line
 
 
data = pd.read_csv('dataset2.csv')
 
X = data.iloc[:, 0:2].values
start_time = time.time()
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(X)
elapsed_time = time.time() - start_time 
y_true = data.iloc[:, 2].values
purity = completeness_score(y_true, labels)
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print("Time taken: ", elapsed_time)
print("Purity: ", purity)
# Out:
# Time taken:  0.09501886367797852
# Purity:  1.0

# %%
# Dbscan - case 3
# Code which output time, purity, distinguishable plot
#conclusive line
 
 
data = pd.read_csv('dataset3.csv')
 
X = data.iloc[:, 0:2].values
start_time = time.time()
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(X)
elapsed_time = time.time() - start_time 
y_true = data.iloc[:, 2].values
purity = completeness_score(y_true, labels)
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print("Time taken: ", elapsed_time)
print("Purity: ", purity)
# Out:
# Time taken:  0.060123443603515625
# Purity:  0.9629805536798237

# %%
# Dbscan - case 4
# Code which output time, purity, distinguishable plot 
#conclusive line
 
 
data = pd.read_csv('dataset4.csv')
 
X = data.iloc[:, 0:2].values
start_time = time.time()
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(X)
elapsed_time = time.time() - start_time 
y_true = data.iloc[:, 2].values
purity = completeness_score(y_true, labels)
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print("Time taken: ", elapsed_time)
print("Purity: ", purity)
# Out:
# Time taken:  0.10359764099121094
# Purity:  1.0

# %%
# Dbscan - case 5
# Code which output time, purity, distinguishable plot
#conclusive line
 
 
data = pd.read_csv('dataset5.csv')
 
X = data.iloc[:, 0:2].values
start_time = time.time()
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(X)
elapsed_time = time.time() - start_time 
y_true = data.iloc[:, 2].values
purity = completeness_score(y_true, labels)
plt.scatter(X[:, 0], X[:, 1], c='green')
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
 
print("Time taken: ", elapsed_time)
print("Purity: ", purity)
# Out:
# Time taken:  0.04491925239562988
# Purity:  0.06558936074506216

# %%
# Happy Ramazan :)
